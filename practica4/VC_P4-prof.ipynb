# %% [markdown]
# #Paquetes necesarios

# %%
# os is used for Ilka's linux :)
import os
os.environ["QT_QPA_PLATFORM"] = "xcb"

import cv2  
import math 

from ultralytics import YOLO

# %% [markdown]
# Modelos preentrenados, visualizando con las utilidades de ultralytics

# %%
# Carga del modelo
#model = YOLO('yolo11n.pt') #Contenedores
#model = YOLO('yolo11n-seg.pt') #Máscaras
model = YOLO('yolo11n-pose.pt')  #Pose

#Para un vídeo 
filename = "TGC23_PdH_C0056cut.mp4"
results = model(filename, show=True)

cv2.destroyAllWindows()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 212.6ms
# video 1/1 (frame 2/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 180.5ms
# video 1/1 (frame 3/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 136.6ms
# video 1/1 (frame 4/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 126.7ms
# video 1/1 (frame 5/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 114.7ms
# video 1/1 (frame 6/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 115.7ms
# video 1/1 (frame 7/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 8/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 117.7ms
# video 1/1 (frame 9/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 115.7ms
# video 1/1 (frame 10/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 112.7ms
# video 1/1 (frame 11/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 115.7ms
# video 1/1 (frame 12/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 112.7ms
# video 1/1 (frame 13/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 14/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 117.7ms
# video 1/1 (frame 15/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 114.7ms
# video 1/1 (frame 16/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 118.7ms
# video 1/1 (frame 17/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 18/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 19/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 20/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 21/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 22/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 23/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 24/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 25/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 26/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 113.7ms
# video 1/1 (frame 27/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 129.7ms
# video 1/1 (frame 28/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 116.7ms
# video 1/1 (frame 29/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 30/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 31/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 32/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 33/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 34/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 35/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 36/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 37/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 38/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 39/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 113.7ms
# video 1/1 (frame 40/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 41/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 42/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 43/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 44/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 45/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 46/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 113.7ms
# video 1/1 (frame 47/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 117.7ms
# video 1/1 (frame 48/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 49/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 50/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 51/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 52/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 53/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 54/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 55/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 56/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 98.7ms
# video 1/1 (frame 57/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 58/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 96.7ms
# video 1/1 (frame 59/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 60/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 61/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 62/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 63/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 98.7ms
# video 1/1 (frame 64/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 65/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 66/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 152.6ms
# video 1/1 (frame 67/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 68/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 69/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 70/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 71/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 72/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 73/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 74/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 75/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 76/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 77/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 78/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 79/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 112.7ms
# video 1/1 (frame 80/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 81/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 82/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 83/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 84/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 99.7ms
# video 1/1 (frame 85/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 86/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 87/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 88/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 89/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 90/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 98.7ms
# video 1/1 (frame 91/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 97.7ms
# video 1/1 (frame 92/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 98.7ms
# video 1/1 (frame 93/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 94/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 95/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 96/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 97/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 98/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 99/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 100/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 101/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 102/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 103/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 104/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 105/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 106/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 107/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 108/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 109/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 110/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 111/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 117.7ms
# video 1/1 (frame 112/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 113/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 116.7ms
# video 1/1 (frame 114/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 115/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 116/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 97.7ms
# video 1/1 (frame 117/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 118/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 119/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 120/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 121/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 122/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 123/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 128.7ms
# video 1/1 (frame 124/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 125/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 116.2ms
# video 1/1 (frame 126/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.8ms
# video 1/1 (frame 127/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 128/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 161.6ms
# video 1/1 (frame 129/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 129.6ms
# video 1/1 (frame 130/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 123.2ms
# video 1/1 (frame 131/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 114.7ms
# video 1/1 (frame 132/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 125.7ms
# video 1/1 (frame 133/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 127.7ms
# video 1/1 (frame 134/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 135/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 112.7ms
# video 1/1 (frame 136/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 137/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 138/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 139/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 112.7ms
# video 1/1 (frame 140/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 141/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 142/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 114.7ms
# video 1/1 (frame 143/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 144/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 145/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 146/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 147/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 148/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 149/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 150/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 151/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 152/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 153/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 154/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 112.7ms
# video 1/1 (frame 155/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 156/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 157/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 158/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 159/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 160/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 161/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 99.7ms
# video 1/1 (frame 162/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 163/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 164/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 165/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 166/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 167/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 168/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 169/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 170/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 122.7ms
# video 1/1 (frame 171/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 172/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.7ms
# video 1/1 (frame 173/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 114.7ms
# video 1/1 (frame 174/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 175/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 176/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 177/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 97.7ms
# video 1/1 (frame 178/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 179/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.7ms
# video 1/1 (frame 180/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 181/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 182/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 183/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 99.7ms
# video 1/1 (frame 184/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.6ms
# video 1/1 (frame 185/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 186/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 187/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 188/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.7ms
# video 1/1 (frame 189/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 146.6ms
# video 1/1 (frame 190/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 191/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 192/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 114.7ms
# video 1/1 (frame 193/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 128.7ms
# video 1/1 (frame 194/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 195/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 196/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 128.7ms
# video 1/1 (frame 197/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 198/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 116.7ms
# video 1/1 (frame 199/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 107.7ms
# video 1/1 (frame 200/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 115.7ms
# video 1/1 (frame 201/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 202/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 127.7ms
# video 1/1 (frame 203/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 204/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.7ms
# video 1/1 (frame 205/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 113.7ms
# video 1/1 (frame 206/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 103.7ms
# video 1/1 (frame 207/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 100.7ms
# video 1/1 (frame 208/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 102.7ms
# video 1/1 (frame 209/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 121.7ms
# video 1/1 (frame 210/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 98.7ms
# video 1/1 (frame 211/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 102.7ms
# video 1/1 (frame 212/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 141.6ms
# video 1/1 (frame 213/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 104.7ms
# video 1/1 (frame 214/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 109.2ms
# video 1/1 (frame 215/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 104.7ms
# video 1/1 (frame 216/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 217/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 116.7ms
# video 1/1 (frame 218/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 103.7ms
# video 1/1 (frame 219/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 130.7ms
# video 1/1 (frame 220/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 98.7ms
# video 1/1 (frame 221/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 104.7ms
# video 1/1 (frame 222/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 102.7ms
# video 1/1 (frame 223/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 100.7ms
# video 1/1 (frame 224/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 145.6ms
# video 1/1 (frame 225/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 109.7ms
# video 1/1 (frame 226/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 227/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 108.7ms
# video 1/1 (frame 228/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 114.7ms
# video 1/1 (frame 229/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 134.6ms
# video 1/1 (frame 230/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 129.7ms
# video 1/1 (frame 231/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 112.7ms
# video 1/1 (frame 232/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 113.7ms
# video 1/1 (frame 233/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 107.7ms
# video 1/1 (frame 234/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 109.7ms
# video 1/1 (frame 235/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 106.7ms
# video 1/1 (frame 236/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 105.7ms
# video 1/1 (frame 237/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 238/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 116.7ms
# video 1/1 (frame 239/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 102.7ms
# video 1/1 (frame 240/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 126.7ms
# video 1/1 (frame 241/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 106.7ms
# video 1/1 (frame 242/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 117.7ms
# video 1/1 (frame 243/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 244/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 103.7ms
# video 1/1 (frame 245/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 246/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 103.7ms
# video 1/1 (frame 247/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 104.7ms
# video 1/1 (frame 248/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 100.7ms
# video 1/1 (frame 249/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 100.7ms
# video 1/1 (frame 250/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 251/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 252/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 106.7ms
# video 1/1 (frame 253/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 173.6ms
# video 1/1 (frame 254/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 179.6ms
# video 1/1 (frame 255/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 106.7ms
# video 1/1 (frame 256/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 102.7ms
# video 1/1 (frame 257/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 106.7ms
# video 1/1 (frame 258/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 103.7ms
# video 1/1 (frame 259/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 260/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 103.7ms
# video 1/1 (frame 261/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 98.7ms
# video 1/1 (frame 262/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 105.7ms
# video 1/1 (frame 263/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 109.7ms
# video 1/1 (frame 264/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 159.6ms
# video 1/1 (frame 265/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 200.3ms
# video 1/1 (frame 266/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 103.7ms
# video 1/1 (frame 267/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 105.7ms
# video 1/1 (frame 268/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 101.7ms
# video 1/1 (frame 269/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 99.7ms
# video 1/1 (frame 270/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 99.7ms
# video 1/1 (frame 271/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 186.5ms
# video 1/1 (frame 272/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 215.4ms
# video 1/1 (frame 273/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 124.7ms
# video 1/1 (frame 274/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 106.7ms
# video 1/1 (frame 275/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 99.7ms
# video 1/1 (frame 276/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 103.7ms
# video 1/1 (frame 277/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 100.7ms
# video 1/1 (frame 278/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 102.5ms
# video 1/1 (frame 279/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 110.7ms
# video 1/1 (frame 280/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 104.7ms
# video 1/1 (frame 281/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 103.7ms
# video 1/1 (frame 282/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 158.6ms
# video 1/1 (frame 283/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 102.7ms
# video 1/1 (frame 284/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 104.7ms
# video 1/1 (frame 285/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 2 persons, 100.7ms
# video 1/1 (frame 286/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 98.7ms
# video 1/1 (frame 287/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 107.7ms
# video 1/1 (frame 288/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 101.7ms
# video 1/1 (frame 289/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 104.7ms
# video 1/1 (frame 290/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 102.7ms
# video 1/1 (frame 291/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 107.7ms
# video 1/1 (frame 292/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 104.7ms
# video 1/1 (frame 293/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 104.7ms
# video 1/1 (frame 294/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 101.7ms
# video 1/1 (frame 295/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 168.5ms
# video 1/1 (frame 296/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 102.7ms
# video 1/1 (frame 297/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 100.7ms
# video 1/1 (frame 298/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 110.7ms
# video 1/1 (frame 299/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 112.7ms
# video 1/1 (frame 300/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 102.7ms
# video 1/1 (frame 301/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 106.7ms
# video 1/1 (frame 302/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 104.7ms
# video 1/1 (frame 303/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 167.6ms
# video 1/1 (frame 304/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 193.5ms
# video 1/1 (frame 305/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 107.7ms
# video 1/1 (frame 306/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 102.7ms
# video 1/1 (frame 307/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 153.6ms
# video 1/1 (frame 308/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 191.5ms
# video 1/1 (frame 309/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 106.7ms
# video 1/1 (frame 310/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 156.1ms
# video 1/1 (frame 311/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 190.5ms
# video 1/1 (frame 312/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 110.7ms
# video 1/1 (frame 313/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 160.1ms
# video 1/1 (frame 314/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 175.5ms
# video 1/1 (frame 315/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 201.5ms
# video 1/1 (frame 316/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 1 person, 257.3ms
# video 1/1 (frame 317/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 205.5ms
# video 1/1 (frame 318/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 209.4ms
# video 1/1 (frame 319/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 114.7ms
# video 1/1 (frame 320/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 112.7ms
# video 1/1 (frame 321/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 322/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 323/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 201.5ms
# video 1/1 (frame 324/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 127.7ms
# video 1/1 (frame 325/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 118.7ms
# video 1/1 (frame 326/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 116.7ms
# video 1/1 (frame 327/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 328/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 329/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.7ms
# video 1/1 (frame 330/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 117.7ms
# video 1/1 (frame 331/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.7ms
# video 1/1 (frame 332/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 124.7ms
# video 1/1 (frame 333/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 113.7ms
# video 1/1 (frame 334/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 123.7ms
# video 1/1 (frame 335/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 336/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 141.6ms
# video 1/1 (frame 337/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (frame 338/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 142.6ms
# video 1/1 (frame 339/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 146.6ms
# video 1/1 (frame 340/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 129.7ms
# video 1/1 (frame 341/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 185.5ms
# video 1/1 (frame 342/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 144.6ms
# video 1/1 (frame 343/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 132.6ms
# video 1/1 (frame 344/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 135.6ms
# video 1/1 (frame 345/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 126.7ms
# video 1/1 (frame 346/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 137.6ms
# video 1/1 (frame 347/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 123.7ms
# video 1/1 (frame 348/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 113.7ms
# video 1/1 (frame 349/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 110.7ms
# video 1/1 (frame 350/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 351/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.7ms
# video 1/1 (frame 352/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 353/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.7ms
# video 1/1 (frame 354/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 123.7ms
# video 1/1 (frame 355/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# video 1/1 (frame 356/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 357/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.7ms
# video 1/1 (frame 358/375) d:\Elena\Cuarto\VC\Visi-n-por-Computador\practica4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.7ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6 #Para un vídeo
#       7 filename = "TGC23_PdH_C0056cut.mp4"
# ----> 8 results = model(filename, show=True)
#      10 cv2.destroyAllWindows()
#
# File d:\Elena\Cuarto\VC\Enviroments\lib\site-packages\ultralytics\engine\model.py:176, in Model.__call__(self, source, stream, **kwargs)
#     147 def __call__(
#     148     self,
#     149     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     150     stream: bool = False,
#     151     **kwargs,
#     152 ) -> list:
#     153     """
#     154     Alias for the predict method, enabling the model instance to be callable for predictions.
#     155
#    (...)
#     174         ...     print(f"Detected {len(r)} objects in image")
#     175     """
# --> 176     return self.predict(source, stream, **kwargs)
#
# File d:\Elena\Cuarto\VC\Enviroments\lib\site-packages\ultralytics\engine\model.py:554, in Model.predict(self, source, stream, predictor, **kwargs)
#     552 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     553     self.predictor.set_prompts(prompts)
# --> 554 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File d:\Elena\Cuarto\VC\Enviroments\lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File d:\Elena\Cuarto\VC\Enviroments\lib\site-packages\torch\utils\_contextlib.py:57, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      54         else:
#      55             # Pass the last request to the generator and get its response
#      56             with ctx_factory():
# ---> 57                 response = gen.send(request)
#      59 # We let the exceptions raised above by the generator's `.throw` or
#      60 # `.send` methods bubble up to our caller, except for StopIteration
#      61 except StopIteration as e:
#      62     # The generator informed us that it is done: take whatever its
#      63     # returned value (if any) was and indicate that we're done too
#      64     # by returning it (see docs for python's return-statement).
#
# File d:\Elena\Cuarto\VC\Enviroments\lib\site-packages\ultralytics\engine\predictor.py:274, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     268     self.results[i].speed = {
#     269         "preprocess": profilers[0].dt * 1e3 / n,
#     270         "inference": profilers[1].dt * 1e3 / n,
#     271         "postprocess": profilers[2].dt * 1e3 / n,
#     272     }
#     273     if self.args.verbose or self.args.save or self.args.save_txt or self.args.show:
# --> 274         s[i] += self.write_results(i, Path(paths[i]), im, s)
#     276 # Print batch results
#     277 if self.args.verbose:
#
# File d:\Elena\Cuarto\VC\Enviroments\lib\site-packages\ultralytics\engine\predictor.py:352, in BasePredictor.write_results(self, i, p, im, s)
#     350     result.save_crop(save_dir=self.save_dir / "crops", file_name=self.txt_path.stem)
#     351 if self.args.show:
# --> 352     self.show(str(p))
#     353 if self.args.save:
#     354     self.save_predicted_images(str(self.save_dir / p.name), frame)
#
# File d:\Elena\Cuarto\VC\Enviroments\lib\site-packages\ultralytics\engine\predictor.py:394, in BasePredictor.show(self, p)
#     392     cv2.resizeWindow(p, im.shape[1], im.shape[0])  # (width, height)
#     393 cv2.imshow(p, im)
# --> 394 cv2.waitKey(300 if self.dataset.mode == "image" else 1)
#
# KeyboardInterrupt:

# %% [markdown]
# Desde cámara, detección con yolo11, modelo nano. Visualización propia con OpenCV

# %%
# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Detecta en la imagen
        results = model(img, stream=True)
        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 206.4ms
# Speed: 4.0ms preprocess, 206.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 230.4ms
# Speed: 7.0ms preprocess, 230.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 169.5ms
# Speed: 2.0ms preprocess, 169.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 161.6ms
# Speed: 4.0ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.7ms
# Speed: 3.0ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 134.6ms
# Speed: 2.0ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.6ms
# Speed: 2.0ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 131.7ms
# Speed: 3.0ms preprocess, 131.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.6ms
# Speed: 4.0ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 131.6ms
# Speed: 3.0ms preprocess, 131.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.7ms
# Speed: 4.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 129.7ms
# Speed: 2.0ms preprocess, 129.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 127.7ms
# Speed: 3.0ms preprocess, 127.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.7ms
# Speed: 3.0ms preprocess, 121.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.7ms
# Speed: 3.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 108.7ms
# Speed: 3.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.7ms
# Speed: 2.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.7ms
# Speed: 2.0ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 109.7ms
# Speed: 3.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 108.7ms
# Speed: 3.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 107.7ms
# Speed: 3.0ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.7ms
# Speed: 3.0ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 104.7ms
# Speed: 3.0ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 105.7ms
# Speed: 3.0ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.7ms
# Speed: 41.9ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.7ms
# Speed: 3.0ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 115.7ms
# Speed: 2.0ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.2ms
# Speed: 2.0ms preprocess, 118.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.7ms
# Confianza ---> 0.63
# Clase --> person
# Speed: 3.0ms preprocess, 109.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 keyboard, 109.7ms
# Confianza ---> 0.43
# Clase --> keyboard
# Confianza ---> 0.35
# Clase --> person
# Confianza ---> 0.26
# Clase --> person
# Speed: 2.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 116.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.43
# Clase --> laptop
# Confianza ---> 0.4
# Clase --> tvmonitor
# Confianza ---> 0.31
# Clase --> person
# Speed: 2.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 tv, 1 keyboard, 114.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.58
# Clase --> keyboard
# Confianza ---> 0.46
# Clase --> chair
# Confianza ---> 0.41
# Clase --> person
# Confianza ---> 0.36
# Clase --> tvmonitor
# Confianza ---> 0.31
# Clase --> chair
# Confianza ---> 0.28
# Clase --> person
# Speed: 3.0ms preprocess, 114.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 1 tv, 1 keyboard, 111.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.72
# Clase --> keyboard
# Confianza ---> 0.57
# Clase --> chair
# Confianza ---> 0.47
# Clase --> tvmonitor
# Confianza ---> 0.38
# Clase --> diningtable
# Confianza ---> 0.3
# Clase --> chair
# Speed: 4.0ms preprocess, 111.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 1 dining table, 1 keyboard, 115.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.69
# Clase --> keyboard
# Confianza ---> 0.62
# Clase --> chair
# Confianza ---> 0.57
# Clase --> diningtable
# Confianza ---> 0.32
# Clase --> chair
# Confianza ---> 0.3
# Clase --> chair
# Speed: 3.0ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 1 dining table, 1 tv, 1 keyboard, 123.7ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.62
# Clase --> keyboard
# Confianza ---> 0.55
# Clase --> chair
# Confianza ---> 0.54
# Clase --> diningtable
# Confianza ---> 0.4
# Clase --> tvmonitor
# Confianza ---> 0.31
# Clase --> chair
# Confianza ---> 0.3
# Clase --> chair
# Speed: 3.0ms preprocess, 123.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 dining table, 1 tv, 1 laptop, 1 mouse, 1 keyboard, 111.7ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.74
# Clase --> keyboard
# Confianza ---> 0.59
# Clase --> diningtable
# Confianza ---> 0.57
# Clase --> chair
# Confianza ---> 0.39
# Clase --> tvmonitor
# Confianza ---> 0.31
# Clase --> mouse
# Confianza ---> 0.26
# Clase --> laptop
# Speed: 3.0ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 dining table, 1 tv, 1 laptop, 2 keyboards, 117.7ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.7
# Clase --> keyboard
# Confianza ---> 0.55
# Clase --> chair
# Confianza ---> 0.54
# Clase --> diningtable
# Confianza ---> 0.49
# Clase --> keyboard
# Confianza ---> 0.36
# Clase --> laptop
# Confianza ---> 0.3
# Clase --> tvmonitor
# Speed: 3.0ms preprocess, 117.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 dining table, 1 tv, 1 laptop, 2 keyboards, 114.7ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.72
# Clase --> keyboard
# Confianza ---> 0.58
# Clase --> diningtable
# Confianza ---> 0.49
# Clase --> chair
# Confianza ---> 0.37
# Clase --> tvmonitor
# Confianza ---> 0.37
# Clase --> keyboard
# Confianza ---> 0.3
# Clase --> laptop
# Speed: 4.0ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 chairs, 1 dining table, 1 laptop, 1 keyboard, 109.7ms
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.64
# Clase --> keyboard
# Confianza ---> 0.55
# Clase --> chair
# Confianza ---> 0.47
# Clase --> diningtable
# Confianza ---> 0.45
# Clase --> laptop
# Confianza ---> 0.34
# Clase --> person
# Confianza ---> 0.32
# Clase --> person
# Confianza ---> 0.3
# Clase --> chair
# Confianza ---> 0.29
# Clase --> person
# Confianza ---> 0.27
# Clase --> chair
# Speed: 3.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 1 dining table, 1 laptop, 1 mouse, 1 keyboard, 110.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.58
# Clase --> keyboard
# Confianza ---> 0.53
# Clase --> laptop
# Confianza ---> 0.49
# Clase --> chair
# Confianza ---> 0.38
# Clase --> diningtable
# Confianza ---> 0.35
# Clase --> person
# Confianza ---> 0.34
# Clase --> mouse
# Confianza ---> 0.29
# Clase --> chair
# Confianza ---> 0.28
# Clase --> chair
# Speed: 2.0ms preprocess, 110.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 2 laptops, 1 keyboard, 113.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.55
# Clase --> chair
# Confianza ---> 0.41
# Clase --> laptop
# Confianza ---> 0.4
# Clase --> keyboard
# Confianza ---> 0.38
# Clase --> laptop
# Confianza ---> 0.33
# Clase --> person
# Confianza ---> 0.29
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Confianza ---> 0.27
# Clase --> chair
# Confianza ---> 0.27
# Clase --> person
# Confianza ---> 0.26
# Clase --> chair
# Speed: 4.0ms preprocess, 113.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 dining table, 1 tv, 2 laptops, 1 mouse, 1 keyboard, 110.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.64
# Clase --> chair
# Confianza ---> 0.5
# Clase --> laptop
# Confianza ---> 0.44
# Clase --> keyboard
# Confianza ---> 0.38
# Clase --> laptop
# Confianza ---> 0.32
# Clase --> person
# Confianza ---> 0.3
# Clase --> chair
# Confianza ---> 0.29
# Clase --> mouse
# Confianza ---> 0.26
# Clase --> tvmonitor
# Confianza ---> 0.26
# Clase --> person
# Confianza ---> 0.26
# Clase --> diningtable
# Speed: 3.0ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 2 laptops, 1 mouse, 1 keyboard, 114.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.68
# Clase --> chair
# Confianza ---> 0.45
# Clase --> chair
# Confianza ---> 0.41
# Clase --> laptop
# Confianza ---> 0.38
# Clase --> laptop
# Confianza ---> 0.3
# Clase --> person
# Confianza ---> 0.3
# Clase --> person
# Confianza ---> 0.29
# Clase --> chair
# Confianza ---> 0.26
# Clase --> mouse
# Confianza ---> 0.26
# Clase --> keyboard
# Speed: 4.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 1 dining table, 2 laptops, 124.7ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.57
# Clase --> chair
# Confianza ---> 0.54
# Clase --> laptop
# Confianza ---> 0.45
# Clase --> chair
# Confianza ---> 0.39
# Clase --> laptop
# Confianza ---> 0.36
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Confianza ---> 0.26
# Clase --> diningtable
# Confianza ---> 0.26
# Clase --> person
# Speed: 3.0ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 2 laptops, 119.7ms
# Confianza ---> 0.89
# Clase --> person
# Confianza ---> 0.64
# Clase --> chair
# Confianza ---> 0.53
# Clase --> laptop
# Confianza ---> 0.43
# Clase --> laptop
# Confianza ---> 0.39
# Clase --> chair
# Speed: 3.0ms preprocess, 119.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 laptop, 115.7ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.54
# Clase --> chair
# Confianza ---> 0.46
# Clase --> laptop
# Confianza ---> 0.35
# Clase --> chair
# Confianza ---> 0.35
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Speed: 3.0ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 dining table, 1 laptop, 117.7ms
# Confianza ---> 0.9
# Clase --> person
# Confianza ---> 0.76
# Clase --> chair
# Confianza ---> 0.48
# Clase --> chair
# Confianza ---> 0.43
# Clase --> laptop
# Confianza ---> 0.31
# Clase --> diningtable
# Confianza ---> 0.28
# Clase --> person
# Speed: 5.0ms preprocess, 117.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 dining table, 1 keyboard, 113.7ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.68
# Clase --> chair
# Confianza ---> 0.45
# Clase --> chair
# Confianza ---> 0.44
# Clase --> diningtable
# Confianza ---> 0.3
# Clase --> person
# Confianza ---> 0.28
# Clase --> keyboard
# Speed: 3.0ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 dining table, 3 laptops, 1 keyboard, 136.6ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.58
# Clase --> chair
# Confianza ---> 0.57
# Clase --> laptop
# Confianza ---> 0.49
# Clase --> chair
# Confianza ---> 0.42
# Clase --> laptop
# Confianza ---> 0.36
# Clase --> keyboard
# Confianza ---> 0.31
# Clase --> person
# Confianza ---> 0.27
# Clase --> laptop
# Confianza ---> 0.26
# Clase --> diningtable
# Speed: 12.0ms preprocess, 136.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 2 laptops, 1 keyboard, 117.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.79
# Clase --> chair
# Confianza ---> 0.52
# Clase --> laptop
# Confianza ---> 0.41
# Clase --> laptop
# Confianza ---> 0.34
# Clase --> keyboard
# Confianza ---> 0.3
# Clase --> chair
# Confianza ---> 0.26
# Clase --> person
# Confianza ---> 0.26
# Clase --> person
# Speed: 3.0ms preprocess, 117.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 2 laptops, 118.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.8
# Clase --> chair
# Confianza ---> 0.58
# Clase --> laptop
# Confianza ---> 0.55
# Clase --> laptop
# Confianza ---> 0.4
# Clase --> chair
# Confianza ---> 0.31
# Clase --> person
# Speed: 2.0ms preprocess, 118.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 2 laptops, 1 keyboard, 116.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.75
# Clase --> chair
# Confianza ---> 0.51
# Clase --> keyboard
# Confianza ---> 0.42
# Clase --> laptop
# Confianza ---> 0.34
# Clase --> chair
# Confianza ---> 0.31
# Clase --> person
# Confianza ---> 0.29
# Clase --> person
# Confianza ---> 0.28
# Clase --> laptop
# Confianza ---> 0.27
# Clase --> person
# Speed: 2.0ms preprocess, 116.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 2 laptops, 1 keyboard, 115.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.64
# Clase --> chair
# Confianza ---> 0.49
# Clase --> laptop
# Confianza ---> 0.46
# Clase --> keyboard
# Confianza ---> 0.4
# Clase --> laptop
# Confianza ---> 0.4
# Clase --> chair
# Confianza ---> 0.29
# Clase --> person
# Speed: 3.0ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 2 laptops, 112.7ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.74
# Clase --> laptop
# Confianza ---> 0.64
# Clase --> chair
# Confianza ---> 0.44
# Clase --> person
# Confianza ---> 0.43
# Clase --> chair
# Confianza ---> 0.42
# Clase --> laptop
# Confianza ---> 0.36
# Clase --> person
# Speed: 3.0ms preprocess, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 2 laptops, 115.7ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.7
# Clase --> laptop
# Confianza ---> 0.53
# Clase --> chair
# Confianza ---> 0.41
# Clase --> chair
# Confianza ---> 0.41
# Clase --> person
# Confianza ---> 0.39
# Clase --> person
# Confianza ---> 0.29
# Clase --> laptop
# Speed: 3.0ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 2 laptops, 124.7ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.66
# Clase --> laptop
# Confianza ---> 0.52
# Clase --> chair
# Confianza ---> 0.5
# Clase --> person
# Confianza ---> 0.41
# Clase --> chair
# Confianza ---> 0.36
# Clase --> person
# Confianza ---> 0.35
# Clase --> person
# Confianza ---> 0.35
# Clase --> laptop
# Speed: 3.0ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 1 laptop, 112.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.64
# Clase --> laptop
# Confianza ---> 0.54
# Clase --> chair
# Confianza ---> 0.45
# Clase --> chair
# Confianza ---> 0.36
# Clase --> chair
# Confianza ---> 0.31
# Clase --> person
# Speed: 3.0ms preprocess, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 2 laptops, 115.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.76
# Clase --> laptop
# Confianza ---> 0.59
# Clase --> chair
# Confianza ---> 0.53
# Clase --> person
# Confianza ---> 0.43
# Clase --> chair
# Confianza ---> 0.33
# Clase --> laptop
# Confianza ---> 0.31
# Clase --> chair
# Confianza ---> 0.29
# Clase --> person
# Speed: 3.0ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 2 laptops, 114.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.76
# Clase --> laptop
# Confianza ---> 0.54
# Clase --> chair
# Confianza ---> 0.47
# Clase --> chair
# Confianza ---> 0.4
# Clase --> person
# Confianza ---> 0.4
# Clase --> person
# Confianza ---> 0.28
# Clase --> laptop
# Confianza ---> 0.27
# Clase --> chair
# Speed: 2.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 2 laptops, 128.2ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.68
# Clase --> laptop
# Confianza ---> 0.55
# Clase --> chair
# Confianza ---> 0.51
# Clase --> person
# Confianza ---> 0.34
# Clase --> chair
# Confianza ---> 0.33
# Clase --> person
# Confianza ---> 0.28
# Clase --> chair
# Confianza ---> 0.27
# Clase --> laptop
# Speed: 4.0ms preprocess, 128.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 2 laptops, 116.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.69
# Clase --> chair
# Confianza ---> 0.68
# Clase --> laptop
# Confianza ---> 0.39
# Clase --> person
# Confianza ---> 0.31
# Clase --> chair
# Confianza ---> 0.28
# Clase --> laptop
# Confianza ---> 0.28
# Clase --> chair
# Speed: 3.0ms preprocess, 116.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 2 laptops, 121.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.73
# Clase --> laptop
# Confianza ---> 0.7
# Clase --> chair
# Confianza ---> 0.64
# Clase --> person
# Confianza ---> 0.48
# Clase --> person
# Confianza ---> 0.32
# Clase --> chair
# Confianza ---> 0.29
# Clase --> laptop
# Confianza ---> 0.28
# Clase --> person
# Speed: 2.0ms preprocess, 121.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 chairs, 1 laptop, 119.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.7
# Clase --> laptop
# Confianza ---> 0.58
# Clase --> chair
# Confianza ---> 0.44
# Clase --> chair
# Confianza ---> 0.43
# Clase --> person
# Confianza ---> 0.39
# Clase --> person
# Confianza ---> 0.3
# Clase --> chair
# Confianza ---> 0.26
# Clase --> person
# Speed: 2.0ms preprocess, 119.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 2 laptops, 115.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.75
# Clase --> laptop
# Confianza ---> 0.75
# Clase --> chair
# Confianza ---> 0.51
# Clase --> person
# Confianza ---> 0.44
# Clase --> person
# Confianza ---> 0.37
# Clase --> chair
# Confianza ---> 0.37
# Clase --> laptop
# Confianza ---> 0.33
# Clase --> person
# Speed: 3.0ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 2 laptops, 111.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.74
# Clase --> laptop
# Confianza ---> 0.7
# Clase --> chair
# Confianza ---> 0.4
# Clase --> person
# Confianza ---> 0.39
# Clase --> person
# Confianza ---> 0.34
# Clase --> laptop
# Confianza ---> 0.28
# Clase --> person
# Confianza ---> 0.28
# Clase --> chair
# Speed: 4.0ms preprocess, 111.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 laptop, 123.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.73
# Clase --> laptop
# Confianza ---> 0.67
# Clase --> chair
# Confianza ---> 0.43
# Clase --> person
# Confianza ---> 0.3
# Clase --> chair
# Speed: 3.0ms preprocess, 123.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 chairs, 2 laptops, 118.7ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.75
# Clase --> laptop
# Confianza ---> 0.74
# Clase --> chair
# Confianza ---> 0.53
# Clase --> person
# Confianza ---> 0.49
# Clase --> person
# Confianza ---> 0.33
# Clase --> chair
# Confianza ---> 0.3
# Clase --> laptop
# Confianza ---> 0.28
# Clase --> chair
# Confianza ---> 0.26
# Clase --> person
# Speed: 4.0ms preprocess, 118.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 2 laptops, 1 keyboard, 115.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.7
# Clase --> chair
# Confianza ---> 0.68
# Clase --> laptop
# Confianza ---> 0.47
# Clase --> person
# Confianza ---> 0.46
# Clase --> person
# Confianza ---> 0.44
# Clase --> keyboard
# Confianza ---> 0.38
# Clase --> chair
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.33
# Clase --> laptop
# Speed: 3.0ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 chairs, 2 laptops, 1 keyboard, 120.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.73
# Clase --> chair
# Confianza ---> 0.54
# Clase --> keyboard
# Confianza ---> 0.51
# Clase --> person
# Confianza ---> 0.49
# Clase --> laptop
# Confianza ---> 0.43
# Clase --> laptop
# Confianza ---> 0.39
# Clase --> chair
# Confianza ---> 0.36
# Clase --> person
# Confianza ---> 0.35
# Clase --> chair
# Confianza ---> 0.33
# Clase --> person
# Speed: 3.0ms preprocess, 120.7ms inference, 45.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 2 laptops, 124.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.68
# Clase --> chair
# Confianza ---> 0.68
# Clase --> laptop
# Confianza ---> 0.46
# Clase --> person
# Confianza ---> 0.46
# Clase --> chair
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.37
# Clase --> person
# Confianza ---> 0.32
# Clase --> laptop
# Speed: 27.9ms preprocess, 124.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 laptop, 114.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.74
# Clase --> chair
# Confianza ---> 0.72
# Clase --> laptop
# Confianza ---> 0.38
# Clase --> chair
# Confianza ---> 0.36
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Speed: 3.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 2 laptops, 1 mouse, 115.7ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.7
# Clase --> chair
# Confianza ---> 0.61
# Clase --> laptop
# Confianza ---> 0.44
# Clase --> person
# Confianza ---> 0.42
# Clase --> chair
# Confianza ---> 0.36
# Clase --> person
# Confianza ---> 0.31
# Clase --> person
# Confianza ---> 0.27
# Clase --> mouse
# Confianza ---> 0.26
# Clase --> laptop
# Speed: 3.0ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 chairs, 1 laptop, 1 keyboard, 114.7ms
# Confianza ---> 0.88
# Clase --> person
# Confianza ---> 0.71
# Clase --> chair
# Confianza ---> 0.62
# Clase --> keyboard
# Confianza ---> 0.48
# Clase --> person
# Confianza ---> 0.44
# Clase --> chair
# Confianza ---> 0.43
# Clase --> person
# Confianza ---> 0.28
# Clase --> laptop
# Confianza ---> 0.28
# Clase --> chair
# Confianza ---> 0.26
# Clase --> person
# Speed: 3.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 1 laptop, 1 keyboard, 116.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.72
# Clase --> laptop
# Confianza ---> 0.49
# Clase --> chair
# Confianza ---> 0.49
# Clase --> chair
# Confianza ---> 0.43
# Clase --> person
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.32
# Clase --> person
# Confianza ---> 0.31
# Clase --> keyboard
# Speed: 3.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 2 laptops, 109.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.82
# Clase --> laptop
# Confianza ---> 0.53
# Clase --> chair
# Confianza ---> 0.45
# Clase --> chair
# Confianza ---> 0.36
# Clase --> laptop
# Confianza ---> 0.32
# Clase --> person
# Confianza ---> 0.3
# Clase --> person
# Speed: 3.0ms preprocess, 109.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 laptop, 115.7ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.83
# Clase --> laptop
# Confianza ---> 0.61
# Clase --> chair
# Confianza ---> 0.41
# Clase --> chair
# Confianza ---> 0.37
# Clase --> person
# Speed: 3.0ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# Seguimiento. Requiere instalar lap con pip install lap

# %%
from collections import defaultdict
import numpy as np

# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car"]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
track_history = defaultdict(lambda: [])
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Seguimiento, con persistencia entre fotogramas
        results = model.track(img, persist=True, classes = [0,1,2])

        if 0:
            if results is not None:
                print(results[0])
                boxes = results[0].boxes.xywh.cpu()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                annotated_frame = results[0].plot()
                for box, track_id in zip(boxes, track_ids):
                    x, y, w, h = box
                    track = track_history[track_id]
                    track.append((float(x), float(y)))
                    if len(track) > 30:
                        track.pop(0)
                    points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                    cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)
                cv2.imshow("YOLO11 Tracking", annotated_frame)
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
        

        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

                #Etiqueta de seguimiento
                if box.id is not None:
                    track_id = str(int(box.id[0].tolist()))
                else:
                    track_id = ''
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, track_id + ' ' + classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 109.7ms
# Speed: 4.0ms preprocess, 109.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.48
# Clase --> person
#
# WARNING: not enough matching points
# 0: 480x640 4 persons, 195.5ms
# Speed: 6.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.41
# Clase --> person
# Confianza ---> 0.23
# Clase --> person
# Confianza ---> 0.21
# Clase --> person
#
# 0: 480x640 1 person, 112.7ms
# Speed: 3.0ms preprocess, 112.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 118.7ms
# Speed: 2.0ms preprocess, 118.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.85
# Clase --> person
#
# 0: 480x640 1 person, 115.7ms
# Speed: 2.0ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.82
# Clase --> person
#
# 0: 480x640 1 person, 118.7ms
# Speed: 4.0ms preprocess, 118.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 107.7ms
# Speed: 2.0ms preprocess, 107.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 114.7ms
# Speed: 3.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 116.7ms
# Speed: 5.0ms preprocess, 116.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 114.7ms
# Speed: 3.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 118.7ms
# Speed: 3.0ms preprocess, 118.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 122.7ms
# Speed: 3.0ms preprocess, 122.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 116.7ms
# Speed: 2.0ms preprocess, 116.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 105.7ms
# Speed: 3.0ms preprocess, 105.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.81
# Clase --> person
#
# 0: 480x640 1 person, 107.7ms
# Speed: 3.0ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 108.7ms
# Speed: 3.0ms preprocess, 108.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 105.7ms
# Speed: 3.0ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 107.7ms
# Speed: 2.0ms preprocess, 107.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 106.7ms
# Speed: 3.0ms preprocess, 106.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 111.7ms
# Speed: 3.0ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 106.7ms
# Speed: 4.0ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 163.6ms
# Speed: 2.0ms preprocess, 163.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 118.7ms
# Speed: 3.0ms preprocess, 118.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 106.7ms
# Speed: 4.0ms preprocess, 106.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 111.7ms
# Speed: 2.0ms preprocess, 111.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 107.7ms
# Speed: 4.0ms preprocess, 107.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 112.7ms
# Speed: 3.0ms preprocess, 112.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 107.7ms
# Speed: 2.0ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 105.7ms
# Speed: 3.0ms preprocess, 105.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 108.7ms
# Speed: 3.0ms preprocess, 108.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 107.7ms
# Speed: 2.0ms preprocess, 107.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 103.7ms
# Speed: 3.0ms preprocess, 103.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 109.7ms
# Speed: 3.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 104.7ms
# Speed: 3.0ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 108.7ms
# Speed: 3.0ms preprocess, 108.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 105.7ms
# Speed: 3.0ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 106.7ms
# Speed: 5.0ms preprocess, 106.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 169.5ms
# Speed: 2.0ms preprocess, 169.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 137.6ms
# Speed: 3.0ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 132.7ms
# Speed: 3.0ms preprocess, 132.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 201.5ms
# Speed: 3.0ms preprocess, 201.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 126.7ms
# Speed: 6.0ms preprocess, 126.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 118.7ms
# Speed: 2.0ms preprocess, 118.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 127.7ms
# Speed: 2.0ms preprocess, 127.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 122.7ms
# Speed: 3.0ms preprocess, 122.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 109.7ms
# Speed: 3.0ms preprocess, 109.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 112.7ms
# Speed: 4.0ms preprocess, 112.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 105.7ms
# Speed: 3.0ms preprocess, 105.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 113.7ms
# Speed: 3.0ms preprocess, 113.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 109.7ms
# Speed: 3.0ms preprocess, 109.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 214.4ms
# Speed: 7.0ms preprocess, 214.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 230.4ms
# Speed: 3.0ms preprocess, 230.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 119.7ms
# Speed: 3.0ms preprocess, 119.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 131.7ms
# Speed: 3.0ms preprocess, 131.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 125.7ms
# Speed: 3.0ms preprocess, 125.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 128.6ms
# Speed: 5.0ms preprocess, 128.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 119.7ms
# Speed: 3.0ms preprocess, 119.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 170.5ms
# Speed: 3.0ms preprocess, 170.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 114.7ms
# Speed: 2.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 106.7ms
# Speed: 5.0ms preprocess, 106.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person

# %% [markdown]
# Intregración con seguimiento (tracking)
# !!!!!!!!!Nota: he tenido que bajar a la versión de python 3.9.5 e instalar lap con pip install lap

# %%
# Carga del modelo
model = YOLO('yolo11n.pt') #Contenedores
#model = YOLO('yolov11n-seg.pt') #Máscaras
#model = YOLO('yolo11n-pose.pt')  #Pose

#Para un vídeo 
filename = "TGC23_PdH_C0056cut.mp4"
results = model.track(source=filename, show=True)  # BoT-SORT tracker (por defecto)
#results = model.track(source=filename, show=True, tracker="bytetrack.yaml")  # ByteTrack tracker

cv2.destroyAllWindows()

# %% [markdown]
# Reconocimiento de caracteres tras instalar pytesseract y tesseract

# %%
# Tesseract
import cv2
import platform
import pytesseract
from pytesseract import Output


if platform.system() == "Windows":
    pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract'
elif platform.system() == "Linux":
    pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'


# Lenguajes disponibles
print(pytesseract.get_languages(config=''))

#Cargo imagen y ocnvierto a RGB
img = cv2.imread('ocr_test.tif') 

if img is not None:
    #Convierte a RGB antes de procesar
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #Texto localizado
    print(pytesseract.image_to_string(img))

    #Texto y localización en imagen de cada palabra
    d = pytesseract.image_to_data(img_rgb, output_type=Output.DICT)

    n_boxes = len(d['text'])
    for i in range(n_boxes):
        #Nivel de confianza
        if int(d['conf'][i]) > 60:
            text = d['text'][i]
            conf = d['conf'][i]
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

            print(f'Texto: {text} ({conf:.2f}%)\nContenedor: {x,y,x+w,y+h}')

    cv2.imshow('img', img_rgb)
    cv2.waitKey(-1)

   

else:
    print('Error de imagen')

# %% [markdown]
# Reconocimiento de caracteres tras instalar easyocr

# %%
import easyocr

#Carga del modelo de lengua
reader = easyocr.Reader(['es']) 

#Reconocimiento de una imagen
res = reader.readtext('ocr_test.tif')

for (bbox, text, prob) in res:
    # Coordenadas en orden 
    (top_left, top_right, bottom_right, bottom_left) = bbox
    print(f'\nTexto: {text}\nProbabilidad: {prob:.2f}\nContenedor: {tuple(map(int, top_left)),tuple(map(int, bottom_right))}')


#Con restricción de caracteres reconocibles
#result = reader.readtext('toy.tif', allowlist ='0123456789')

# %% [markdown]
# Procesar el video de ejemplo además de varios videos, hechos por nosotras o encontrados por internet
# * Detecte y siga las personas y vehículos presentes
# * Detecte y lea las matrículas de los vehículos presentes
# * Cuente el total de cada clase
# * vuelque a disco un video que visualice los resultados
# * genere un archivo csv con el resultado de la detección y seguimiento. Se sugiere un formato con al
#   menos los siguientes campos:
#
# Se considerarán extras:
# * Determine el flujo de personas y vehículos en el video de test en distintas direcciones ( vehículos
#   que dejan la imagne por la derecha, por la izquierda, etc)
# * Evaluar dos alternativas para la detección de matrículas: basada en YOLO, y basada en contornos
# * Anonimizar a las personas y vehículos presentes en un video
# * En el caso de haberse apuntado al Autumn Campus Makeathon InnovAction Canarias, se valorará la
#     aplicación de habilidaddes adquiridas en esta práctica
